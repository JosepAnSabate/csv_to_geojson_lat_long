# %%
import geopandas
import pandas as pd

# %%
path = 'C:/Users/34639/Downloads/world_countries_copia.csv'

# %%
df = pd.read_csv(path, sep=',')

# %%
df
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]

# %%
if 'longitude' in df:
        df.rename(columns = {'longitude':'long.', 'latitude':'lat.'}, inplace = True)

# %%
dfx = df.copy()

# %%
dfx
# Out:
#     country       lat.      long.                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]

# %%
df = df

# %%
path2 = 'C:/Users/34639/Downloads/world_countries_long.csv'

# %%
df.to_csv(path2, index=False)

# %%
df['LONG.,LAT.']=df.apply(lambda x:'%s/%s' % (x['lat.'],x['long.']),axis=1)

# %%
df = df.drop(columns=['lat.','long.'])

# %%
df
# Out:
#     country                  name                     LONG.,LAT.
# 0        AD               Andorra   42.546245/1.6015540000000001
# 1        AE  United Arab Emirates   23.424076/53.847818000000004
# 2        AF           Afghanistan             33.93911/67.709953
# 3        AG   Antigua and Barbuda  17.060816/-61.796428000000006
# 4        AI              Anguilla           18.220554/-63.068615
# ..      ...                   ...                            ...
# 240      YE                 Yemen   15.552726999999999/48.516388
# 241      YT               Mayotte             -12.8275/45.166244
# 242      ZA          South Africa           -30.559482/22.937506
# 243      ZM                Zambia           -13.133897/27.849332
# 244      ZW              Zimbabwe           -19.015438/29.154857
#
# [245 rows x 3 columns]

# %%
path3 = 'C:/Users/34639/Downloads/world_countries_diagonal.csv'

# %%
df.to_csv(path3, index=False)

# %%
df
# Out:
#     country                  name                     LONG.,LAT.
# 0        AD               Andorra   42.546245/1.6015540000000001
# 1        AE  United Arab Emirates   23.424076/53.847818000000004
# 2        AF           Afghanistan             33.93911/67.709953
# 3        AG   Antigua and Barbuda  17.060816/-61.796428000000006
# 4        AI              Anguilla           18.220554/-63.068615
# ..      ...                   ...                            ...
# 240      YE                 Yemen   15.552726999999999/48.516388
# 241      YT               Mayotte             -12.8275/45.166244
# 242      ZA          South Africa           -30.559482/22.937506
# 243      ZM                Zambia           -13.133897/27.849332
# 244      ZW              Zimbabwe           -19.015438/29.154857
#
# [245 rows x 3 columns]

# %%
df3 = pd.DataFrame({'SENDFROM': {0: 'xx@gmail.com', 1: 'yy@xxx.com'},
                   'test': {0: 'xxxx@vvv.com;yyy@gggfg.com;tiitioo@ggg.com',
                            1: 'ggg@vvv.com;yyy@gggfg.com;vvv@ggg.com'}})

# %%
df3
# Out:
#        SENDFROM                                        test
# 0  xx@gmail.com  xxxx@vvv.com;yyy@gggfg.com;tiitioo@ggg.com
# 1    yy@xxx.com       ggg@vvv.com;yyy@gggfg.com;vvv@ggg.com

# %%
df3['testing'] = df3['test'].str.split(';').str[0]

# %%
df3
# Out:
#        SENDFROM                                        test       testing
# 0  xx@gmail.com  xxxx@vvv.com;yyy@gggfg.com;tiitioo@ggg.com  xxxx@vvv.com
# 1    yy@xxx.com       ggg@vvv.com;yyy@gggfg.com;vvv@ggg.com   ggg@vvv.com

# %%
df
# Out:
#     country       lat.      long.                  name  \
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
#                         long.,lat.
# 0     42.546245,1.6015540000000001
# 1     23.424076,53.847818000000004
# 2               33.93911,67.709953
# 3    17.060816,-61.796428000000006
# 4             18.220554,-63.068615
# ..                             ...
# 240   15.552726999999999,48.516388
# ...

# %%
df = df.drop(columns=['lat.', 'long.'])

# %%
df
# Out:
#     country                  name                     long.,lat.
# 0        AD               Andorra   42.546245,1.6015540000000001
# 1        AE  United Arab Emirates   23.424076,53.847818000000004
# 2        AF           Afghanistan             33.93911,67.709953
# 3        AG   Antigua and Barbuda  17.060816,-61.796428000000006
# 4        AI              Anguilla           18.220554,-63.068615
# ..      ...                   ...                            ...
# 240      YE                 Yemen   15.552726999999999,48.516388
# 241      YT               Mayotte             -12.8275,45.166244
# 242      ZA          South Africa           -30.559482,22.937506
# 243      ZM                Zambia           -13.133897,27.849332
# 244      ZW              Zimbabwe           -19.015438,29.154857
#
# [245 rows x 3 columns]

# %%
if 'long.,lat.' in df:
    df['longitude'] = df['long.,lat.'].str.split(',').str[0]
    df['latitude'] = df['long.,lat.'].str.split(',').str[1]

# %%
df
# Out:
#     country                  name                     long.,lat.  \
# 0        AD               Andorra   42.546245,1.6015540000000001
# 1        AE  United Arab Emirates   23.424076,53.847818000000004
# 2        AF           Afghanistan             33.93911,67.709953
# 3        AG   Antigua and Barbuda  17.060816,-61.796428000000006
# 4        AI              Anguilla           18.220554,-63.068615
# ..      ...                   ...                            ...
# 240      YE                 Yemen   15.552726999999999,48.516388
# 241      YT               Mayotte             -12.8275,45.166244
# 242      ZA          South Africa           -30.559482,22.937506
# 243      ZM                Zambia           -13.133897,27.849332
# 244      ZW              Zimbabwe           -19.015438,29.154857
#
#               longitude             latitude
# 0             42.546245   1.6015540000000001
# 1             23.424076   53.847818000000004
# 2              33.93911            67.709953
# ...

# %%
dfx
# Out:
#     country       lat.      long.                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]

# %%
dfx['LONG.-LAT.']=df.apply(lambda x:'%s%s' % (x['lat.'],x['long.']),axis=1)

# %%
dfx
# Out:
#     country       lat.      long.                  name  \
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
#                           LONG-LAT
# 0     42.546245,1.6015540000000001
# 1     23.424076,53.847818000000004
# 2               33.93911,67.709953
# 3    17.060816,-61.796428000000006
# 4             18.220554,-63.068615
# ..                             ...
# 240   15.552726999999999,48.516388
# ...

# %%
dfx = dfx.drop(columns=['lat.','long.'])

# %%
dfx
# Out:
#     country                  name                       LONG-LAT
# 0        AD               Andorra   42.546245,1.6015540000000001
# 1        AE  United Arab Emirates   23.424076,53.847818000000004
# 2        AF           Afghanistan             33.93911,67.709953
# 3        AG   Antigua and Barbuda  17.060816,-61.796428000000006
# 4        AI              Anguilla           18.220554,-63.068615
# ..      ...                   ...                            ...
# 240      YE                 Yemen   15.552726999999999,48.516388
# 241      YT               Mayotte             -12.8275,45.166244
# 242      ZA          South Africa           -30.559482,22.937506
# 243      ZM                Zambia           -13.133897,27.849332
# 244      ZW              Zimbabwe           -19.015438,29.154857
#
# [245 rows x 3 columns]

# %%
path5 = 'C:/Users/34639/Downloads/world_countries_coma_barra_bo.csv'

# %%
dfx.to_csv(path5, index=False)

# %%
dfx
# Out:
#     country                  name                       LONG-LAT
# 0        AD               Andorra   42.546245,1.6015540000000001
# 1        AE  United Arab Emirates   23.424076,53.847818000000004
# 2        AF           Afghanistan             33.93911,67.709953
# 3        AG   Antigua and Barbuda  17.060816,-61.796428000000006
# 4        AI              Anguilla           18.220554,-63.068615
# ..      ...                   ...                            ...
# 240      YE                 Yemen   15.552726999999999,48.516388
# 241      YT               Mayotte             -12.8275,45.166244
# 242      ZA          South Africa           -30.559482,22.937506
# 243      ZM                Zambia           -13.133897,27.849332
# 244      ZW              Zimbabwe           -19.015438,29.154857
#
# [245 rows x 3 columns]

# %%
if 'LONG-LAT' in dfx:
        if dfx['LONG-LAT'].str.contains(',').any():
            y = 5

# %%
y
# Out:
# 5

# %%
if 'LONG-LAT' in dfx:
    if dfx['LONG-LAT'].str.contains(',').any():
        dfx['longitude'] = dfx['LONG-LAT'].str.split(',').str[0]
        dfx['latitude'] = dfx['LONG-LAT'].str.split(',').str[1]

# %%
dfx
# Out:
#     country                  name                       LONG-LAT  \
# 0        AD               Andorra   42.546245,1.6015540000000001
# 1        AE  United Arab Emirates   23.424076,53.847818000000004
# 2        AF           Afghanistan             33.93911,67.709953
# 3        AG   Antigua and Barbuda  17.060816,-61.796428000000006
# 4        AI              Anguilla           18.220554,-63.068615
# ..      ...                   ...                            ...
# 240      YE                 Yemen   15.552726999999999,48.516388
# 241      YT               Mayotte             -12.8275,45.166244
# 242      ZA          South Africa           -30.559482,22.937506
# 243      ZM                Zambia           -13.133897,27.849332
# 244      ZW              Zimbabwe           -19.015438,29.154857
#
#               longitude             latitude
# 0             42.546245   1.6015540000000001
# 1             23.424076   53.847818000000004
# 2              33.93911            67.709953
# ...
